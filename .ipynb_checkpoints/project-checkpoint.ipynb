# %%
#Importing packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#loading the data files into pandas dataframe
gross = pd.read_csv('data/bom.movie_gross.csv')
imdb_name = pd.read_csv('data/imdb.name.basics.csv')
imdb_title_akas = pd.read_csv('data/imdb.title.akas.csv')
imdb_title_basics = pd.read_csv('data/imdb.title.basics.csv')
imdb_title_crew = pd.read_csv('data/imdb.title.crew.csv')
imdb_title_principals = pd.read_csv('data/imdb.title.principals.csv')
imdb_title_ratings = pd.read_csv('data/imdb.title.ratings.csv')
rt_movie_info = pd.read_csv('data/rt.movie_info.tsv', delimiter = '\t')
rt_reviews = pd.read_csv('data/rt.reviews.tsv', delimiter = '\t', encoding = 'unicode_escape')
tmdb_movies = pd.read_csv('data/tmdb.movies.csv')
tn_movie_budgets = pd.read_csv('data/tn.movie_budgets.csv') #No Missing values

# %%
# setting and renaming index of tmdb_movies dataset
tmdb_movies.set_index('Unnamed: 0',inplace = True)
tmdb_movies.index.rename('index',inplace = True)

# %%
#Filled missing values with of gross foriegn value to 0 to convert the type of the column to float
gross.foreign_gross = gross.foreign_gross.fillna(0)

# %%
#This function takes a dataframe and column name as arguments
#It removes '$' and ',' from the column values and convert the column type to float
#This function also divides the number with a million to make the numbers easy to read
def string_to_float(df,column):
    df[column] =  df[column].replace({'\$':''}, regex = True)
    df[column] =  df[column].replace({',':''}, regex = True)
    df[column] =  round((df[column].astype(float))/1000000, 2)

# Calling the function on all columns from all datasets to get desired result
string_to_float(tn_movie_budgets,'production_budget')
string_to_float(tn_movie_budgets,'domestic_gross')
string_to_float(tn_movie_budgets,'worldwide_gross')
string_to_float(gross,'foreign_gross')

# %%
#since domestic_gross was already a float dividing it by a million to have same unit of gross throughout the project
gross.domestic_gross = gross.domestic_gross/1000000

# %%
#Creating a new column profit for profit/loss of movies
tn_movie_budgets['profit'] =  tn_movie_budgets['worldwide_gross'] - tn_movie_budgets['production_budget']

# %%
# top ten movies according to profit
#top_grossing_movies = list(tn_movie_budgets.sort_values(by = 'profit', ascending = True)['movie'])
# find movies that are profitable and not profitable
#tn_movie_budgets.sort_values(by = 'profit', ascending = False)['profit'].hist()
#sequels how good are sequels
#
tn_movie_budgets.sort_values(by = 'profit', ascending = False).head(10)
profitable_movies = list(tn_movie_budgets.sort_values(by = 'profit', ascending = False)['movie'].head(50))
not_profitable_movies = list(tn_movie_budgets.sort_values(by = 'profit')['movie'].head(50))

# %%
# Two datasets imdb_title_basics and tn_movie_budgets are merged to get profit and genres together in one table

merged = pd.merge(imdb_title_basics[['tconst', 'start_year', 'runtime_minutes', 'genres','primary_title']], tn_movie_budgets[['release_date', 'movie', 'production_budget', 'domestic_gross', 'worldwide_gross', 'profit']], left_on = 'primary_title', right_on = 'movie', how='inner')
merged.drop(columns=['movie'], inplace = True)

# %%
#Merging gross and tn_movie_budgets to get profit and studios in same table
#profit_studio = pd.merge(gross[['title', 'studio', 'year']], tn_movie_budgets[['release_date', 'movie', 'profit']], left_on = 'title', right_on = 'movie', how='inner')
merged = pd.merge(merged, gross[['title', 'studio', 'year']], left_on = 'primary_title', right_on = 'title', how='left')
merged.drop(columns=['title'], inplace = True)

# %%
merged.drop(columns=['year'], inplace = True)
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  start_year  runtime_minutes                   genres  \
# 1747  tt1775309        2011             93.0                   Horror
# 2776  tt8852130        2018            115.0                   Family
# 2775  tt2495766        2012              NaN                Adventure
# 3360  tt4154756        2018            149.0  Action,Adventure,Sci-Fi
# 12    tt0369610        2015            124.0  Action,Adventure,Sci-Fi
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 1747                  Avatar  Dec 18, 2009              425.0          760.51
# 2776                 Titanic  Dec 19, 1997              200.0          659.36
# 2775                 Titanic  Dec 19, 1997              200.0          659.36
# 3360  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio
# 1747          2776.35  2351.35    NaN
# 2776          2208.21  2008.21    NaN
# 2775          2208.21  2008.21    NaN
# 3360          2048.13  1748.13     BV
# 12            1648.85  1433.85   Uni.

# %%
#Merging our table with imdb_title_crew to get the crew for each movie in same table
merged = pd.merge(merged, imdb_title_crew, on = 'tconst', how='left')

# %%
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  start_year  runtime_minutes                   genres  \
# 1747  tt1775309        2011             93.0                   Horror
# 2776  tt8852130        2018            115.0                   Family
# 2775  tt2495766        2012              NaN                Adventure
# 3360  tt4154756        2018            149.0  Action,Adventure,Sci-Fi
# 12    tt0369610        2015            124.0  Action,Adventure,Sci-Fi
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 1747                  Avatar  Dec 18, 2009              425.0          760.51
# 2776                 Titanic  Dec 19, 1997              200.0          659.36
# 2775                 Titanic  Dec 19, 1997              200.0          659.36
# 3360  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio            directors  \
# 1747          2776.35  2351.35    NaN            nm3786927
# 2776          2208.21  2008.21    NaN           nm10047650
# 2775          2208.21  2008.21    NaN  nm4430776,nm5410036
# 3360          2048.13  1748.13     BV  nm0751577,nm0751648
# 12            1648.85  1433.85   Uni.            nm1119880
#
#                                                 writers
# 1747                                nm2179863,nm4392664
# 2776                                         nm10047650
# 2775                                          nm5410036
# 3360  nm1321655,nm1321656,nm0498278,nm0456158,nm0800...
# 12    nm0415425,nm0798646,nm1119880,nm2081046,nm0000341

# %%
#Merge to get the ratings in same table
merged = pd.merge(merged, imdb_title_ratings, on = 'tconst', how = 'left')

# %%
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  start_year  runtime_minutes                   genres  \
# 1747  tt1775309        2011             93.0                   Horror
# 2776  tt8852130        2018            115.0                   Family
# 2775  tt2495766        2012              NaN                Adventure
# 3360  tt4154756        2018            149.0  Action,Adventure,Sci-Fi
# 12    tt0369610        2015            124.0  Action,Adventure,Sci-Fi
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 1747                  Avatar  Dec 18, 2009              425.0          760.51
# 2776                 Titanic  Dec 19, 1997              200.0          659.36
# 2775                 Titanic  Dec 19, 1997              200.0          659.36
# 3360  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio            directors  \
# 1747          2776.35  2351.35    NaN            nm3786927
# 2776          2208.21  2008.21    NaN           nm10047650
# 2775          2208.21  2008.21    NaN  nm4430776,nm5410036
# 3360          2048.13  1748.13     BV  nm0751577,nm0751648
# 12            1648.85  1433.85   Uni.            nm1119880
#
#                                                 writers  averagerating  \
# 1747                                nm2179863,nm4392664            6.1
# 2776                                         nm10047650            NaN
# 2775                                          nm5410036            6.2
# 3360  nm1321655,nm1321656,nm0498278,nm0456158,nm0800...            8.5
# 12    nm0415425,nm0798646,nm1119880,nm2081046,nm0000341            7.0
#
#       numvotes
# 1747      43.0
# 2776       NaN
# 2775      20.0
# 3360  670926.0
# 12    539338.0

# %%
#Merge to get the language and popularity in same table
merged = pd.merge(merged, tmdb_movies[['original_language', 'popularity', 'original_title']],right_on = 'original_title', left_on = 'primary_title', how='left')

# %%
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  start_year  runtime_minutes                   genres  \
# 2260  tt1775309        2011             93.0                   Horror
# 3849  tt8852130        2018            115.0                   Family
# 3848  tt2495766        2012              NaN                Adventure
# 4572  tt4154756        2018            149.0  Action,Adventure,Sci-Fi
# 12    tt0369610        2015            124.0  Action,Adventure,Sci-Fi
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 2260                  Avatar  Dec 18, 2009              425.0          760.51
# 3849                 Titanic  Dec 19, 1997              200.0          659.36
# 3848                 Titanic  Dec 19, 1997              200.0          659.36
# 4572  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio            directors  \
# 2260          2776.35  2351.35    NaN            nm3786927
# 3849          2208.21  2008.21    NaN           nm10047650
# 3848          2208.21  2008.21    NaN  nm4430776,nm5410036
# 4572          2048.13  1748.13     BV  nm0751577,nm0751648
# 12            1648.85  1433.85   Uni.            nm1119880
#
#                                                 writers  averagerating  \
# 2260                                nm2179863,nm4392664            6.1
# 3849                                         nm10047650            NaN
# 3848                                          nm5410036            6.2
# 4572  nm1321655,nm1321656,nm0498278,nm0456158,nm0800...            8.5
# 12    nm0415425,nm0798646,nm1119880,nm2081046,nm0000341            7.0
#
#       numvotes original_language  popularity          original_title
# 2260      43.0                en      26.526                  Avatar
# 3849       NaN               NaN         NaN                     NaN
# 3848      20.0               NaN         NaN                     NaN
# 4572  670926.0                en      80.773  Avengers: Infinity War
# 12    539338.0                en      20.709          Jurassic World

# %%
#renaming the columns 
merged.rename(columns={"averagerating": "rating", "numvotes": "votes", "original_language": "language"}, inplace = True)
merged.drop(columns=['original_title', 'start_year'], inplace = True)

# %%
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  runtime_minutes                   genres  \
# 2260  tt1775309             93.0                   Horror
# 3849  tt8852130            115.0                   Family
# 3848  tt2495766              NaN                Adventure
# 4572  tt4154756            149.0  Action,Adventure,Sci-Fi
# 12    tt0369610            124.0  Action,Adventure,Sci-Fi
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 2260                  Avatar  Dec 18, 2009              425.0          760.51
# 3849                 Titanic  Dec 19, 1997              200.0          659.36
# 3848                 Titanic  Dec 19, 1997              200.0          659.36
# 4572  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio            directors  \
# 2260          2776.35  2351.35    NaN            nm3786927
# 3849          2208.21  2008.21    NaN           nm10047650
# 3848          2208.21  2008.21    NaN  nm4430776,nm5410036
# 4572          2048.13  1748.13     BV  nm0751577,nm0751648
# 12            1648.85  1433.85   Uni.            nm1119880
#
#                                                 writers  rating     votes  \
# 2260                                nm2179863,nm4392664     6.1      43.0
# 3849                                         nm10047650     NaN       NaN
# 3848                                          nm5410036     6.2      20.0
# 4572  nm1321655,nm1321656,nm0498278,nm0456158,nm0800...     8.5  670926.0
# 12    nm0415425,nm0798646,nm1119880,nm2081046,nm0000341     7.0  539338.0
#
#      language  popularity
# 2260       en      26.526
# 3849      NaN         NaN
# 3848      NaN         NaN
# 4572       en      80.773
# 12         en      20.709

# %%
# Modifying column values
#Removing the commas and conerting them to list of strings
merged['directors'] = merged['directors'].str.split(",") 
merged['writers'] = merged['writers'].str.split(",") 
merged['genres'] = merged['genres'].str.split(",")

# %%
#Removing duplicated rows
#  merged.drop_duplicates(subset = 'title')

# %%
#Getting director names from imdb name and putting them in the columns
# This function looks through the imdb_name dataset and find the corresponding primary name for identifiers
def get_names(lis):
    li = []
    if not isinstance(lis, float):
        for item in lis:
            li.append(list(imdb_name.loc[imdb_name.nconst == item ,'primary_name'])[0])
    return li
    
merged['directors'] = merged['directors'].apply(get_names)
merged['writers'] = merged['writers'].apply(get_names)

# %%
merged.sort_values(by = 'profit', ascending = False).head()
# Out:
#          tconst  runtime_minutes                       genres  \
# 2260  tt1775309             93.0                     [Horror]
# 3849  tt8852130            115.0                     [Family]
# 3848  tt2495766              NaN                  [Adventure]
# 4572  tt4154756            149.0  [Action, Adventure, Sci-Fi]
# 12    tt0369610            124.0  [Action, Adventure, Sci-Fi]
#
#                primary_title  release_date  production_budget  domestic_gross  \
# 2260                  Avatar  Dec 18, 2009              425.0          760.51
# 3849                 Titanic  Dec 19, 1997              200.0          659.36
# 3848                 Titanic  Dec 19, 1997              200.0          659.36
# 4572  Avengers: Infinity War  Apr 27, 2018              300.0          678.82
# 12            Jurassic World  Jun 12, 2015              215.0          652.27
#
#       worldwide_gross   profit studio                    directors  \
# 2260          2776.35  2351.35    NaN               [Atsushi Wada]
# 3849          2208.21  2008.21    NaN                  [Ravi Punj]
# 3848          2208.21  2008.21    NaN  [Pete Meads, Kevin Lincoln]
# 4572          2048.13  1748.13     BV   [Anthony Russo, Joe Russo]
# 12            1648.85  1433.85   Uni.            [Colin Trevorrow]
#
#                                                 writers  rating     votes  \
# 2260                     [Yûsuke Yamada, Teruo Noguchi]     6.1      43.0
# 3849                                        [Ravi Punj]     NaN       NaN
# 3848                                    [Kevin Lincoln]     6.2      20.0
# 4572  [Christopher Markus, Stephen McFeely, Stan Lee...     8.5  670926.0
# 12    [Rick Jaffa, Amanda Silver, Colin Trevorrow, D...     7.0  539338.0
#
#      language  popularity
# 2260       en      26.526
# 3849      NaN         NaN
# 3848      NaN         NaN
# 4572       en      80.773
# 12         en      20.709

# %%
#######  PROTOTYPE DATASET   ######
#Dictionary
###profit: float
###director: list of strings
###writer: list of strings
###actor: list of strings
###budget: float
###region: string
###release_date: string
###studio: string
###genre: list of strings
###rating: float

dictt = {'movie': ['Titanic', 'Avatar','Avengers'],
         'budget': [100, 200,400],
         'domestic_gross': [100,234,100],
         'worldwide_gross': [200,332,102],
         'profit' : [200,300,500],
         'director' : [['name1', 'name2'], ['name3'], ['name', 'nammme']],
         'writer' : [['name4', 'name5'], ['name6'], ['name', 'nammme']],
         'actor' : [['name7'], ['name8', 'name9'], ['name', 'nammme']],
         'region': ['US', 'US', 'US'],
         'release_date': ['12/12/2009','3/2/2011', '5/3/2017' ],
         'studio' : ['BV', 'Sony', 'Marvel'],
         'genre' : [['Action','Adventure','Sci-Fi'], ['Action','Adventure','Family'],['Action','Adventure','Family','Sci-Fi']],
         'rating': [8.5, 9, 9.5], #imdb_title_ratings
         'popularity': [33,56,78], 
         'numvotes': [234,3456,5654]
        }
df = pd.DataFrame(data=dictt)
df
# Out:
#       movie  budget  domestic_gross  worldwide_gross  profit        director  \
# 0   Titanic     100             100              200     200  [name1, name2]
# 1    Avatar     200             234              332     300         [name3]
# 2  Avengers     400             100              102     500  [name, nammme]
#
#            writer           actor region release_date  studio  \
# 0  [name4, name5]         [name7]     US   12/12/2009      BV
# 1         [name6]  [name8, name9]     US     3/2/2011    Sony
# 2  [name, nammme]  [name, nammme]     US     5/3/2017  Marvel
#
#                                  genre  rating  popularity  numvotes
# 0          [Action, Adventure, Sci-Fi]     8.5          33       234
# 1          [Action, Adventure, Family]     9.0          56      3456
# 2  [Action, Adventure, Family, Sci-Fi]     9.5          78      5654

# %%
#getting the names of actors
#actors =  imdb_title_principals[imdb_title_principals.category == 'actor'][['tconst','nconst']]

# %%
#actors.rename(columns={"nconst": "actor"}, inplace = True)

# %%
#merged = pd.merge(merged, actors, on = 'tconst', how='inner')

# %%
#merged.head()

# %%
#dictt =  actors.to_dict()

#dictt = dictt['actor']

# %%
#This function gets the nconst from actor column and return name of that actor
#def get_name(string):
    #return imdb_name[imdb_name.nconst == str(string)]['primary_name']
    
#merged['actor'] = merged['actor'].apply(get_name)

# %%
#Dataset of top 20 prfotable movies
top_20 = merged.sort_values(by = 'profit', ascending = False).head(20)

# %%
# Genres of Top 20 Profitable movies
top_20_genres = list(top_20.genres)
flat_list = [item for sublist in top_20_genres for item in sublist]
top_profitable_genre = set(flat_list)
top_profitable_genre
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Horror',
#  'Musical',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Thriller'}

# %%
# Directors of top_20 Profitable movies
top_20_directors = list(top_20.directors)
flat_list = [item for sublist in top_20_directors for item in sublist]
top_profitable_directors = set(flat_list)
top_profitable_directors
# Out:
# {'Adam Green',
#  'Anthony Russo',
#  'Atsushi Wada',
#  'Bill Condon',
#  'Chi-kin Kwok',
#  'Chris Buck',
#  'Christophe Gans',
#  'Colin Trevorrow',
#  'J.A. Bayona',
#  'James Wan',
#  'Jennifer Lee',
#  'Joe Russo',
#  'Joss Whedon',
#  'Kevin Lincoln',
#  'Pete Meads',
#  'Ravi Punj',
#  'Ryan Coogler'}

# %%
# Writers of top_20 Profitable movies
top_20_writers = list(top_20.writers)
flat_list = [item for sublist in top_20_writers for item in sublist]
top_profitable_writers = set(flat_list)
top_profitable_writers
# Out:
# {'Adam Green',
#  'Amanda Silver',
#  'Bill Mantlo',
#  'Chi-kin Kwok',
#  'Chris Buck',
#  'Chris Morgan',
#  'Christophe Gans',
#  'Christopher Markus',
#  'Colin Trevorrow',
#  'Derek Connolly',
#  'Don Heck',
#  'Evan Spiliotopoulos',
#  'Gabrielle-Suzanne Barbot de Villeneuve',
#  'Gary Scott Thompson',
#  'Hans Christian Andersen',
#  'Jack Kirby',
#  'Jeanne-Marie Leprince de Beaumont',
#  'Jennifer Lee',
#  'Jim Starlin',
#  'Joe Robert Cole',
#  'Joe Simon',
#  'Joss Whedon',
#  'Ka Yee Yim',
#  'Keith Giffen',
#  'Kevin Lincoln',
#  'Larry Lieber',
#  'Linda Woolverton',
#  'Michael Crichton',
#  'Ravi Punj',
#  'Rick Jaffa',
#  'Ryan Coogler',
#  'Sandra Vo-Anh',
#  'Shane Morris',
#  'Stan Lee',
#  'Stephen Chbosky',
#  'Stephen McFeely',
#  'Steve Englehart',
#  'Steve Gan',
#  'Teruo Noguchi',
#  'Yûsuke Yamada',
#  'Zak Penn'}

# %%
# Corelation between budget and profit
merged[['production_budget', 'profit']].corr()
# Out:
#                    production_budget   profit
# production_budget            1.00000  0.64793
# profit                       0.64793  1.00000

# %%
top_20[['production_budget', 'profit']].corr()
# Out:
#                    production_budget    profit
# production_budget           1.000000  0.795472
# profit                      0.795472  1.000000

# %%
ax = top_20[['production_budget','profit']].plot(kind='bar', title ="Profit and production Budget", figsize=(10, 8), legend=True, fontsize=12)
#ax.set_xlabel("Product", fontsize=12)
#ax.set_ylabel("V", fontsize=12)
plt.show()

# %%
#rating and profit graph
plt.plot( 'profit', 'rating', data=top_20[['rating', 'profit']])
plt.show()
